# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
color = sns.color_palette()

# %%
aisles = pd.read_csv('data/aisles.csv')
departments = pd.read_csv('data/departments.csv')
order_products__prior = pd.read_csv('data/order_products__prior.csv')
order_products__train = pd.read_csv('data/order_products__train.csv')
orders = pd.read_csv('data/orders.csv')
products = pd.read_csv('data/products.csv')
sample_submission = pd.read_csv('data/sample_submission.csv')

# %%
aisles
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
aisles.describe()
# Out:
#          aisle_id
# count  134.000000
# mean    67.500000
# std     38.826537
# min      1.000000
# 25%     34.250000
# 50%     67.500000
# 75%    100.750000
# max    134.000000

# %%
departments
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
departments.describe()
# Out:
#        department_id
# count      21.000000
# mean       11.000000
# std         6.204837
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# 75%        16.000000
# max        21.000000

# %%
order_products__prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
order_products__prior.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  3.243449e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710749e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873007e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.559430e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.711048e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565514e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00

# %%
order_products__train
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0               1       49302                  1          1
# 1               1       11109                  2          1
# 2               1       10246                  3          0
# 3               1       49683                  4          0
# 4               1       43633                  5          1
# ...           ...         ...                ...        ...
# 1384612   3421063       14233                  3          1
# 1384613   3421063       35548                  4          1
# 1384614   3421070       35951                  1          1
# 1384615   3421070       16953                  2          1
# 1384616   3421070        4724                  3          1
#
# [1384617 rows x 4 columns]

# %%
order_products__train.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  1.384617e+06  1.384617e+06       1.384617e+06  1.384617e+06
# mean   1.706298e+06  2.555624e+04       8.758044e+00  5.985944e-01
# std    9.897326e+05  1.412127e+04       7.423936e+00  4.901829e-01
# min    1.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.433700e+05  1.338000e+04       3.000000e+00  0.000000e+00
# 50%    1.701880e+06  2.529800e+04       7.000000e+00  1.000000e+00
# 75%    2.568023e+06  3.794000e+04       1.200000e+01  1.000000e+00
# max    3.421070e+06  4.968800e+04       8.000000e+01  1.000000e+00

# %%
orders
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
orders.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
_ = sns.countplot(orders.order_hour_of_day)
plt.show()

# %%
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
products.describe()
# Out:
#          product_id      aisle_id  department_id
# count  49688.000000  49688.000000   49688.000000
# mean   24844.500000     67.769582      11.728687
# std    14343.834425     38.316162       5.850410
# min        1.000000      1.000000       1.000000
# 25%    12422.750000     35.000000       7.000000
# 50%    24844.500000     69.000000      13.000000
# 75%    37266.250000    100.000000      17.000000
# max    49688.000000    134.000000      21.000000

# %%
sample_submission.products.value_counts()
# Out:
# 39276 29259    75000
# Name: products, dtype: int64

# %%
sample_submission
# Out:
#        order_id     products
# 0            17  39276 29259
# 1            34  39276 29259
# 2           137  39276 29259
# 3           182  39276 29259
# 4           257  39276 29259
# ...         ...          ...
# 74995   3420740  39276 29259
# 74996   3420877  39276 29259
# 74997   3420888  39276 29259
# 74998   3420989  39276 29259
# 74999   3421054  39276 29259
#
# [75000 rows x 2 columns]

# %%
products[products.product_id == 29259]
# Out:
#        product_id  product_name  aisle_id  department_id
# 29258       29259  Baby Bananas        24              4

# %%
cnt_srs = orders.eval_set.value_counts()

plt.figure(figsize=(5,5))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Eval set type', fontsize=12)
plt.title('Count of rows in each dataset', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
def get_unique_count(x):
    return len(np.unique(x))

cnt_srs = orders.groupby("eval_set")["user_id"].aggregate(get_unique_count)
cnt_srs
# Out:
# eval_set
# prior    206209
# test      75000
# train    131209
# Name: user_id, dtype: int64

# %% [markdown]
# So there are 206,209 customers in total. Out of which, the last purchase of 131,209 customers are given as train set and we need to predict for the rest 75,000 customers.
#
# Now let us validate the claim that 4 to 100 orders of a customer are given.

# %%
cnt_srs = orders.groupby("user_id")["order_number"].aggregate(np.max).reset_index()
cnt_srs = cnt_srs.order_number.value_counts()

plt.figure(figsize=(16,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[2])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Maximum order number', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# So there are no orders less than 4 and the maximum is capped at 100 as given in the introduction.

# %% [markdown]
# ## Ordering habit changes with day of the week

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="order_dow", data=orders, color=color[0])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Day of week', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Frequency of order by week day", fontsize=15)
plt.show()

# %% [markdown]
# Seems like 0 and 1 is Saturday and Sunday when the orders are high and low during Wednesday.

# %% [markdown]
# ## Order Distribution w.r.t time of day

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="order_hour_of_day", data=orders)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Hour of day', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Frequency of order by hour of day", fontsize=15)
plt.show()

# %% [markdown]
# So majority of the orders are made during day time.
#
# Now, combining the day of week and hour of day to see the distribution.

# %%
grouped_df = orders.groupby(["order_dow", "order_hour_of_day"])["order_number"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('order_dow', 'order_hour_of_day', 'order_number')

plt.figure(figsize=(12,7))
sns.heatmap(grouped_df, cmap="YlGnBu")
plt.title("Frequency of Day of week Vs Hour of day")
plt.show()

# %% [markdown]
# Seems Satuday evenings and Sunday mornings are the prime time for orders.

# %% [markdown]
# ## Time interval between the orders.

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="days_since_prior_order", data=orders, color=color[4])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Days since prior order', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Frequency distribution by days since prior order", fontsize=15)
plt.show()

# %% [markdown]
# Looks like customers order once in every week (check the peak at 7 days) or once in a month (peak at 30 days). We could also see smaller peaks at 14, 21 and 28 days (weekly intervals).
#
# Since our objective is to figure out the re-orders, let us check out the re-order percentage in prior set and train set.

# %%
# percentage of re-orders in prior set #
order_products__prior.reordered.sum() / order_products__prior.shape[0]
# Out:
# 0.5896974667922161

# %%
# percentage of re-orders in train set #
order_products__train.reordered.sum() / order_products__train.shape[0]
# Out:
# 0.5985944127509629

# %% [markdown]
# On an average, about 59% of the products in an order are re-ordered products.

# %% [markdown]
# ## Number of products bought in each order

# %%
grouped_df = order_products__train.groupby("order_id")["add_to_cart_order"].aggregate("max").reset_index()
cnt_srs = grouped_df.add_to_cart_order.value_counts()

plt.figure(figsize=(16,6))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Number of products in the given order', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# A right tailed distribution with the maximum value at 5.!

# %% [markdown]
# ## Merge the product details with the order_prior details.

# %%
order_products_prior_df = order_products__prior.copy()
order_products_prior_df = pd.merge(order_products_prior_df, products, on='product_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, aisles, on='aisle_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, departments, on='department_id', how='left')
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle  department
# 0        86             16                eggs  dairy eggs
# 1        83              4    fresh vegetables     produce
# 2       104             13   spices seasonings      pantry
# 3        19             13       oils vinegars      pantry
# 4        17             13  baking ingredients      pantry

# %%
cnt_srs = order_products_prior_df['product_name'].value_counts().reset_index().head(20)
cnt_srs.columns = ['product_name', 'frequency_count']
cnt_srs
# Out:
#                 product_name  frequency_count
# 0                     Banana           472565
# 1     Bag of Organic Bananas           379450
# 2       Organic Strawberries           264683
# 3       Organic Baby Spinach           241921
# 4       Organic Hass Avocado           213584
# 5            Organic Avocado           176815
# 6                Large Lemon           152657
# 7               Strawberries           142951
# 8                      Limes           140627
# 9         Organic Whole Milk           137905
# 10       Organic Raspberries           137057
# 11      Organic Yellow Onion           113426
# 12            Organic Garlic           109778
# 13          Organic Zucchini           104823
# 14       Organic Blueberries           100060
# 15            Cucumber Kirby            97315
# 16        Organic Fuji Apple            89632
# 17             Organic Lemon            87746
# 18  Apple Honeycrisp Organic            85020
# ...

# %% [markdown]
# Most of them are organic products.! Also majority of them are fruits.

# %% [markdown]
# ## Important aisles

# %%
cnt_srs = order_products_prior_df['aisle'].value_counts().head(20)
plt.figure(figsize=(10,5))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Aisle', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# The top two aisles are fresh fruits and fresh vegetables.!

# %% [markdown]
# ## Important Departments

# %%
plt.figure(figsize=(10,5))
temp_series = order_products_prior_df['department'].value_counts()
labels = (np.array(temp_series.index))
sns.barplot(labels, temp_series)
plt.title("Departments distribution", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Produce is the largest department

# %% [markdown]
# ## Re-order ratio of each department

# %%
grouped_df = order_products_prior_df.groupby(["department"])["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(10,6))
sns.pointplot(grouped_df['department'].values, grouped_df['reordered'].values, alpha=0.8, color=color[2])
plt.ylabel('Reorder ratio', fontsize=12)
plt.xlabel('Department', fontsize=12)
plt.title("Department wise reorder ratio", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
order_products_prior_df.groupby(["department"])["reordered"].aggregate("mean").reset_index()
# Out:
#          department  reordered
# 0           alcohol   0.569924
# 1            babies   0.578971
# 2            bakery   0.628141
# 3         beverages   0.653460
# 4         breakfast   0.560922
# 5              bulk   0.577040
# 6      canned goods   0.457405
# 7        dairy eggs   0.669969
# 8              deli   0.607719
# 9   dry goods pasta   0.461076
# 10           frozen   0.541885
# 11        household   0.402178
# 12    international   0.369229
# 13     meat seafood   0.567674
# 14          missing   0.395849
# 15            other   0.407980
# 16           pantry   0.346721
# 17    personal care   0.321129
# 18             pets   0.601285
# 19          produce   0.649913
# 20           snacks   0.574180

# %% [markdown]
# Personal care has lowest reorder ratio and dairy eggs have highest reorder ratio.

# %% [markdown]
# ## Aisle - Reorder ratio:

# %%
order_products_prior_df.groupby(["department_id", "aisle"])["reordered"].aggregate("mean").reset_index()
# Out:
#      department_id                    aisle  reordered
# 0                1  frozen appetizers sides   0.525557
# 1                1     frozen breads doughs   0.539992
# 2                1         frozen breakfast   0.626221
# 3                1           frozen dessert   0.420777
# 4                1             frozen juice   0.450855
# ..             ...                      ...        ...
# 129             20               lunch meat   0.606517
# 130             20           prepared meals   0.619759
# 131             20    prepared soups salads   0.596597
# 132             20   tofu meat alternatives   0.607775
# 133             21                  missing   0.395849
#
# [134 rows x 3 columns]

# %%
grouped_df = order_products_prior_df.groupby(["department_id", "aisle"])["reordered"].aggregate("mean").reset_index()

fig, ax = plt.subplots(figsize=(16,20))
ax.scatter(grouped_df.reordered.values, grouped_df.department_id.values)
for i, txt in enumerate(grouped_df.aisle.values):
    ax.annotate(txt, (grouped_df.reordered.values[i], grouped_df.department_id.values[i]), rotation=45, ha='center', va='center', color='green')
plt.xlabel('Reorder Ratio')
plt.ylabel('department_id')
plt.title("Reorder ratio of different aisles", fontsize=15)
plt.show()

# %%
order_products_prior_df["add_to_cart_order_mod"] = order_products_prior_df["add_to_cart_order"].copy()
order_products_prior_df["add_to_cart_order_mod"].loc[order_products_prior_df["add_to_cart_order_mod"]>70] = 70
grouped_df = order_products_prior_df.groupby(["add_to_cart_order_mod"])["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(16,8))
sns.pointplot(grouped_df['add_to_cart_order_mod'].values, grouped_df['reordered'].values, alpha=0.8, color=color[2])
plt.ylabel('Reorder ratio', fontsize=12)
plt.xlabel('Add to cart order', fontsize=12)
plt.title("Add to cart order - Reorder ratio", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Looks like the products that are added to the cart initially are more likely to be reordered again compared to the ones added later. This makes sense as well since we tend to first order all the products we used to buy frequently and then look out for the new products available.

# %% [markdown]
# ## Reorder ratio by Time based variables:

# %%
prior = order_products__prior.copy()
train = order_products__train.copy()
orders_copy = orders.copy()
prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
train
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0               1       49302                  1          1
# 1               1       11109                  2          1
# 2               1       10246                  3          0
# 3               1       49683                  4          0
# 4               1       43633                  5          1
# ...           ...         ...                ...        ...
# 1384612   3421063       14233                  3          1
# 1384613   3421063       35548                  4          1
# 1384614   3421070       35951                  1          1
# 1384615   3421070       16953                  2          1
# 1384616   3421070        4724                  3          1
#
# [1384617 rows x 4 columns]

# %%
prior_and_train_merge = pd.concat([prior, train])
prior_and_train_merge
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0               2       33120                  1          1
# 1               2       28985                  2          1
# 2               2        9327                  3          0
# 3               2       45918                  4          1
# 4               2       30035                  5          0
# ...           ...         ...                ...        ...
# 1384612   3421063       14233                  3          1
# 1384613   3421063       35548                  4          1
# 1384614   3421070       35951                  1          1
# 1384615   3421070       16953                  2          1
# 1384616   3421070        4724                  3          1
#
# [33819106 rows x 4 columns]

# %%
# Out:
# 33819106

# %%
orders_copy
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
orders_copy[orders_copy.eval_set == 'test']
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 38        2774568        3     test            13          5
# 44         329954        4     test             6          3
# 53        1528013        6     test             4          3
# 96        1376945       11     test             8          6
# 102       1356845       12     test             6          1
# ...           ...      ...      ...           ...        ...
# 3420918   2728930   206202     test            23          2
# 3420929    350108   206204     test             5          4
# 3421001   1043943   206206     test            68          0
# 3421018   2821651   206207     test            17          2
# 3421068    803273   206208     test            50          5
#
#          order_hour_of_day  days_since_prior_order
# 38                      15                    11.0
# 44                      12                    30.0
# 53                      16                    22.0
# ...

# %%
orders_copy.groupby(['order_id'])['eval_set'].aggregate('count').reset_index()
# Out:
#          order_id  eval_set
# 0               1         1
# 1               2         1
# 2               3         1
# 3               4         1
# 4               5         1
# ...           ...       ...
# 3421078   3421079         1
# 3421079   3421080         1
# 3421080   3421081         1
# 3421081   3421082         1
# 3421082   3421083         1
#
# [3421083 rows x 2 columns]

# %%
orders_copy.pivot_table(columns='eval_set', index='user_id', values='order_number', aggfunc='max')
# Out:
# eval_set  prior  test  train
# user_id
# 1          10.0   NaN   11.0
# 2          14.0   NaN   15.0
# 3          12.0  13.0    NaN
# 4           5.0   6.0    NaN
# 5           4.0   NaN    5.0
# ...         ...   ...    ...
# 206205      3.0   NaN    4.0
# 206206     67.0  68.0    NaN
# 206207     16.0  17.0    NaN
# 206208     49.0  50.0    NaN
# 206209     13.0   NaN   14.0
#
# [206209 rows x 3 columns]

# %%
orders_copy.pivot_table?

# %%
order_and_products_merged = pd.merge(orders_copy, prior_and_train_merge, on='order_id', how='left')
#order_and_products_merged = pd.merge(order_and_products_merged, train, on='order_id', how='left', left_index=True)

# %%
#order_products_prior_df = pd.merge(order_products_prior_df, products, on='product_id', how='left')

# %%
pd.merge?

# %%
order_and_products_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33894106 entries, 0 to 33894105
# Data columns (total 10 columns):
# order_id                  int64
# user_id                   int64
# eval_set                  object
# order_number              int64
# order_dow                 int64
# order_hour_of_day         int64
# days_since_prior_order    float64
# product_id                float64
# add_to_cart_order         float64
# reordered                 float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 2.8+ GB

# %%
order_and_products_merged[order_and_products_merged.isnull().any(axis=1)]
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 33893977   3154581   206209    prior             1          3
# 33893978   3154581   206209    prior             1          3
# 33893979   3154581   206209    prior             1          3
# 33893980   3154581   206209    prior             1          3
# 33893981   3154581   206209    prior             1          3
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN       196.0
# 1                         8                     NaN     14084.0
# ...

# %%
bool_order_no_1 = order_and_products_merged['order_number'] == 1
order_and_products_merged['days_since_prior_order'][bool_order_no_1] = 0
# Out:
# /Users/jyothirmayeen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
order_and_products_merged[order_and_products_merged.isnull().any(axis=1)]
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 384        2774568        3     test            13          5
# 403         329954        4     test             6          3
# 464        1528013        6     test             4          3
# 1086       1376945       11     test             8          6
# 1161       1356845       12     test             6          1
# ...            ...      ...      ...           ...        ...
# 33892542   2728930   206202     test            23          2
# 33892729    350108   206204     test             5          4
# 33893066   1043943   206206     test            68          0
# 33893290   2821651   206207     test            17          2
# 33893968    803273   206208     test            50          5
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 384                      15                    11.0         NaN
# 403                      12                    30.0         NaN
# ...

# %%
order_and_products_merged.set_index(['eval_set', 'user_id', 'order_id', 'product_id'])
# Out:
#                                       order_number  order_dow  \
# eval_set user_id order_id product_id
# prior    1       2539329  196.0                  1          2
#                           14084.0                1          2
#                           12427.0                1          2
#                           26088.0                1          2
#                           26405.0                1          2
# ...                                            ...        ...
# train    206209  272231   40603.0               14          6
#                           15655.0               14          6
#                           42606.0               14          6
#                           37966.0               14          6
#                           39216.0               14          6
#
#                                       order_hour_of_day  \
# eval_set user_id order_id product_id
# prior    1       2539329  196.0                       8
# ...

# %%
order_and_products_merged['eval_set'].unique()
# Out:
# array(['prior', 'train', 'test'], dtype=object)

# %%
total_users = len(order_and_products_merged.user_id.unique())
total_users
# Out:
# 206209

# %%
top_three_for_each_user = dict()
for i in range(2):
    user = i+1
    #print(user)
    df_for_user = order_and_products_merged[order_and_products_merged.user_id == user]
    products_temp = df_for_user.product_id.value_counts().reset_index()['index'][:3]
    print((products_temp))
#    top_three_for_each_user[user] = [k for k in products_temp]
    top_three_for_each_user[user] = []
    for j in range(3):
        k = products_temp[0]
        print(k)
        product_name = products[products.product_id == k]
        print(product_name)
        product_name = product_name['product_name']
        print((product_name))
        top_three_for_each_user[user].append(product_name)
    print("User ID: ", user, " Products: ", top_three_for_each_user[user])
    #[key:value f]
# Out:
# 0      196.0
# 1    12427.0
# 2    10258.0
# Name: index, dtype: float64
# 196.0
#      product_id product_name  aisle_id  department_id
# 195         196         Soda        77              7
# 195    Soda
# Name: product_name, dtype: object
# 196.0
#      product_id product_name  aisle_id  department_id
# 195         196         Soda        77              7
# 195    Soda
# Name: product_name, dtype: object
# 196.0
#      product_id product_name  aisle_id  department_id
# 195         196         Soda        77              7
# 195    Soda
# Name: product_name, dtype: object
# User ID:  1  Products:  [195    Soda
# Name: product_name, dtype: object, 195    Soda
# Name: product_name, dtype: object, 195    Soda
# Name: product_name, dtype: object]
# 0    32792.0
# 1    24852.0
# 2    47209.0
# Name: index, dtype: float64
# 32792.0
#        product_id                    product_name  aisle_id  department_id
# 32791       32792  Chipotle Beef & Pork Realstick        23             19
# ...

# %%
products_temp[0]
# Out:
# 32792.0

# %%
c = dict()
k = 1
c[k] = 2
c[k+1] = 3
c
# Out:
# {1: 2, 2: 3}

# %%
order_and_products_merged[order_and_products_merged['eval_set'] == 'test']
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 384        2774568        3     test            13          5
# 403         329954        4     test             6          3
# 464        1528013        6     test             4          3
# 1086       1376945       11     test             8          6
# 1161       1356845       12     test             6          1
# ...            ...      ...      ...           ...        ...
# 33892542   2728930   206202     test            23          2
# 33892729    350108   206204     test             5          4
# 33893066   1043943   206206     test            68          0
# 33893290   2821651   206207     test            17          2
# 33893968    803273   206208     test            50          5
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 384                      15                    11.0         NaN
# 403                      12                    30.0         NaN
# ...
